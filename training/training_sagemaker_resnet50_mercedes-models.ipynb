# %%
import sagemaker
from sagemaker.pytorch import PyTorch

# %%
# Define input image dimensions for resizing
height = 448
width = 448

# Define model hyperparameters
lr = 0.01
momentum = 0.9
T_0 = 225 # e.g. 899 / 4 (train_dataset_size / batch_size)
T_mult = 1
epochs = 20
batch_size = 4 # For both train and test sets

# Define number of layers for the ResNet neural network, select from [18, 34, 50 ,101, 152]
num_layers = 50

pretrained_weights = True
unfreeze_all_layers = False # i.e. Default: 'False', unfreezes last layer only for tuning

train_augmentation = False

# %%
# model = './model/resnet_sgd_cosineannealing_inference.py'
model = './model/resnet_sgd_cosineannealing_inference.py'

model_save_name = 'ResNet{}-{}x{}-variants-5'.format(num_layers, height, width)

model_save_path = 's3://car-tagging-datasets/sagemaker-models/trained-model-output'
model_code_save_path = 's3://car-tagging-datasets/sagemaker-models/trained-model-custom-code'

# %%
# Warm Restart Parameters:

bucket = None
saved_model_path = None

# Uncomment (if necessary) and amend the below paths for warm restarts using custom pre-trained weights

# bucket = 'custom-labels-console-eu-west-1-52749662e9'
# saved_model_id = 'resnet50-sgd-cosineannealing-448x448-2021-01-08-14-07-00-745'
# saved_model_path = 'for-custom-labels/train-dataset-augmented/sagemaker-pytorch-models/{}/output/model.tar.gz'.format(saved_model_id)

# %%
train = 's3://car-tagging-datasets/all-variants/variants-5/train/'

test_complex = 's3://car-tagging-datasets/all-variants/variants-5/test-complex/'

test_showroom = 's3://car-tagging-datasets/all-variants/variants-5/test/'

# %%
sagemaker_session = sagemaker.Session()

role = sagemaker.get_execution_role()

#Check the status of dataloader
estimator = PyTorch(entry_point=model,
                    role=role,
                    framework_version='1.4.0',
                    py_version='py3',
                    instance_count=1,
                    instance_type='ml.g4dn.xlarge',
                    base_job_name=model_save_name,
                    output_path=model_save_path,
#                     code_location=custom_code_uri,
                    metric_definitions=[
                        {'Name': 'train:loss', 'Regex': 'train Loss: (.*?);'},
                        {'Name': 'train:acc', 'Regex': 'train Acc: (.*?);'},
                        {'Name': 'validation:loss', 'Regex': 'validation Loss: (.*?);'},
                        {'Name': 'validation:acc', 'Regex': 'validation Acc: (.*?);'},
                        {'Name': 'learning_rate', 'Regex': 'lr: (.*?);'},
                        {'Name': 'epoch', 'Regex': 'epoch: (.*?);'},
                        {'Name': 'train_f1_score', 'Regex': 'train Avg. F1 Score: (.*?);'},
                        {'Name': 'validation_f1_score', 'Regex': 'validation Avg. F1 Score: (.*?);'},
                        {'Name': 'test_f1_score', 'Regex': 'test Avg. F1 Score: (.*?);'},
                        {'Name': 'classification_report', 'Regex': 'classification_report: (.*?);'}
                    ],
                    hyperparameters={
                        'image-height': height,
                        'image-width': width,
                        'batch-size': batch_size,
                        'epochs': epochs,
                        'lr': lr,
                        'momentum': momentum,
                        'T_0': T_0,
                        'T_mult': T_mult,
                        'num-layers': num_layers,
                        'pretrained-weights': pretrained_weights,
                        's3-bucket': bucket,
                        'warm-restart': saved_model_path,
                        'unfreeze-all-layers': unfreeze_all_layers,
                        'train-augmentation': train_augmentation
                    })

# %%
estimator.fit({'train': train,
               'validation': test_complex,
               'test': test_showroom})
# Out:
# 2021-06-02 09:49:08 Starting - Starting the training job...
# 2021-06-02 09:49:30 Starting - Launching requested ML instancesProfilerReport-1622627347: InProgress
# ......
# 2021-06-02 09:50:30 Starting - Preparing the instances for training......
# 2021-06-02 09:51:31 Downloading - Downloading input data...
# 2021-06-02 09:51:52 Training - Downloading the training image......
# 2021-06-02 09:53:05 Training - Training image download completed. Training in progress..bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2021-06-02 09:53:07,115 sagemaker-containers INFO     Imported framework sagemaker_pytorch_container.training
# 2021-06-02 09:53:07,136 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2021-06-02 09:53:07,139 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2021-06-02 09:53:07,450 sagemaker-containers INFO     Module default_user_module_name does not provide a setup.py.
# Generating setup.py
# 2021-06-02 09:53:07,450 sagemaker-containers INFO     Generating setup.cfg
# 2021-06-02 09:53:07,451 sagemaker-containers INFO     Generating MANIFEST.in
# 2021-06-02 09:53:07,451 sagemaker-containers INFO     Installing module with the following command:
# /opt/conda/bin/python3.6 -m pip install .
# Processing /tmp/tmpkd7cx0su/module_dir
# Building wheels for collected packages: default-user-module-name
#   Building wheel for default-user-module-name (setup.py): started
#   Building wheel for default-user-module-name (setup.py): finished with status 'done'
#   Created wheel for default-user-module-name: filename=default_user_module_name-1.0.0-py2.py3-none-any.whl size=11205 sha256=bfe1552c0c39a15409bb8e498cb805e9e2c151efb7ed5b4b5fb531b34bde8068
#   Stored in directory: /tmp/pip-ephem-wheel-cache-vlrsvy3w/wheels/9c/95/09/32a6a1b1fb006800d523cb6ae03bb6f06c1dbbea432471b92c
# Successfully built default-user-module-name
# Installing collected packages: default-user-module-name
# Successfully installed default-user-module-name-1.0.0
# 2021-06-02 09:53:09,838 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "test": "/opt/ml/input/data/test",
#         "validation": "/opt/ml/input/data/validation",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "num-layers": 50,
#         "image-width": 448,
#         "T_0": 225,
#         "lr": 0.01,
#         "train-augmentation": false,
#         "unfreeze-all-layers": false,
#         "pretrained-weights": true,
#         "momentum": 0.9,
#         "batch-size": 4,
#         "warm-restart": null,
#         "image-height": 448,
#         "s3-bucket": null,
#         "epochs": 20,
#         "T_mult": 1
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "test": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "validation": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "ResNet50-448x448-orientation-view-phase-2021-06-02-09-49-07-532",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://car-tagging-datasets/ResNet50-448x448-orientation-view-phase-2021-06-02-09-49-07-532/source/sourcedir.tar.gz",
#     "module_name": "resnet_sgd_cosineannealing_inference",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "resnet_sgd_cosineannealing_inference.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"T_0":225,"T_mult":1,"batch-size":4,"epochs":20,"image-height":448,"image-width":448,"lr":0.01,"momentum":0.9,"num-layers":50,"pretrained-weights":true,"s3-bucket":null,"train-augmentation":false,"unfreeze-all-layers":false,"warm-restart":null}
# SM_USER_ENTRY_POINT=resnet_sgd_cosineannealing_inference.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["test","train","validation"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=resnet_sgd_cosineannealing_inference
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://car-tagging-datasets/ResNet50-448x448-orientation-view-phase-2021-06-02-09-49-07-532/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"test":"/opt/ml/input/data/test","train":"/opt/ml/input/data/train","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"T_0":225,"T_mult":1,"batch-size":4,"epochs":20,"image-height":448,"image-width":448,"lr":0.01,"momentum":0.9,"num-layers":50,"pretrained-weights":true,"s3-bucket":null,"train-augmentation":false,"unfreeze-all-layers":false,"warm-restart":null},"input_config_dir":"/opt/ml/input/config","input_data_config":{"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"ResNet50-448x448-orientation-view-phase-2021-06-02-09-49-07-532","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://car-tagging-datasets/ResNet50-448x448-orientation-view-phase-2021-06-02-09-49-07-532/source/sourcedir.tar.gz","module_name":"resnet_sgd_cosineannealing_inference","network_interface_name":"eth0","num_cpus":4,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"resnet_sgd_cosineannealing_inference.py"}
# SM_USER_ARGS=["--T_0","225","--T_mult","1","--batch-size","4","--epochs","20","--image-height","448","--image-width","448","--lr","0.01","--momentum","0.9","--num-layers","50","--pretrained-weights","True","--s3-bucket","","--train-augmentation","False","--unfreeze-all-layers","False","--warm-restart",""]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TEST=/opt/ml/input/data/test
# SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_NUM-LAYERS=50
# SM_HP_IMAGE-WIDTH=448
# SM_HP_T_0=225
# SM_HP_LR=0.01
# SM_HP_TRAIN-AUGMENTATION=false
# SM_HP_UNFREEZE-ALL-LAYERS=false
# SM_HP_PRETRAINED-WEIGHTS=true
# SM_HP_MOMENTUM=0.9
# SM_HP_BATCH-SIZE=4
# SM_HP_WARM-RESTART=
# SM_HP_IMAGE-HEIGHT=448
# SM_HP_S3-BUCKET=
# SM_HP_EPOCHS=20
# SM_HP_T_MULT=1
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
#
# Invoking script with the following command:
#
# /opt/conda/bin/python3.6 resnet_sgd_cosineannealing_inference.py --T_0 225 --T_mult 1 --batch-size 4 --epochs 20 --image-height 448 --image-width 448 --lr 0.01 --momentum 0.9 --num-layers 50 --pretrained-weights True --s3-bucket  --train-augmentation False --unfreeze-all-layers False --warm-restart
#
#
# GPU NAME: Tesla T4
# Epoch 1/20
# ----------
# [2021-06-02 09:53:16.728 algo-1:43 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2021-06-02 09:53:16.728 algo-1:43 INFO hook.py:192] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2021-06-02 09:53:16.728 algo-1:43 INFO hook.py:237] Saving to /opt/ml/output/tensors
# [2021-06-02 09:53:16.728 algo-1:43 INFO state_store.py:67] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2021-06-02 09:53:16.741 algo-1:43 INFO hook.py:382] Monitoring the collections: losses
# [2021-06-02 09:53:16.741 algo-1:43 INFO hook.py:443] Hook is writing from the hook with pid: 43
#
# train Loss: 1.2809; train Acc: 0.7825;
# validation Loss: 2.2203; validation Acc: 0.6149;
# epoch: 1; lr: 0.0009963431452563332;
#
# Epoch 2/20
# ----------
# train Loss: 0.9976; train Acc: 0.8476;
# validation Loss: 1.7451; validation Acc: 0.7143;
# epoch: 2; lr: 0.003588292715785618;
#
# Epoch 3/20
# ----------
# train Loss: 0.6349; train Acc: 0.8866;
# validation Loss: 1.6352; validation Acc: 0.6894;
# epoch: 3; lr: 0.006742860236609076;
#
# Epoch 4/20
# ----------
# train Loss: 0.5087; train Acc: 0.9126;
# validation Loss: 4.2429; validation Acc: 0.5528;
# epoch: 4; lr: 0.009202833017478422;
#
# Epoch 5/20
# ----------
# train Loss: 0.5287; train Acc: 0.9033;
# validation Loss: 1.3717; validation Acc: 0.7640;
# epoch: 5; lr: 1.2179748700878457e-05;
#
# Epoch 6/20
# ----------
# train Loss: 0.7134; train Acc: 0.9040;
# validation Loss: 1.6285; validation Acc: 0.7391;
# epoch: 6; lr: 0.0012150247217412185;
#
# Epoch 7/20
# ----------
# train Loss: 0.3913; train Acc: 0.9139;
# validation Loss: 1.6647; validation Acc: 0.7453;
# epoch: 7; lr: 0.003926323364164684;
#
# Epoch 8/20
# ----------
# train Loss: 0.5669; train Acc: 0.9238;
# validation Loss: 3.9880; validation Acc: 0.6460;
# epoch: 8; lr: 0.007065522149122709;
#
# Epoch 9/20
# ----------
# train Loss: 0.4902; train Acc: 0.9157;
# validation Loss: 3.1481; validation Acc: 0.6894;
# epoch: 9; lr: 0.009381533400219317;
#
# Epoch 10/20
# ----------
# train Loss: 0.4037; train Acc: 0.9269;
# validation Loss: 1.7107; validation Acc: 0.7888;
# epoch: 10; lr: 4.865965629214875e-05;
#
# Epoch 11/20
# ----------
# train Loss: 0.6904; train Acc: 0.9077;
# validation Loss: 1.8990; validation Acc: 0.7764;
# epoch: 11; lr: 0.0014521463173173949;
#
# Epoch 12/20
# ----------
# train Loss: 0.4786; train Acc: 0.9275;
# validation Loss: 1.8020; validation Acc: 0.7826;
# epoch: 12; lr: 0.004269584857187943;
#
# Epoch 13/20
# ----------
# train Loss: 0.4213; train Acc: 0.9325;
# validation Loss: 2.0286; validation Acc: 0.7578;
# epoch: 13; lr: 0.007378121045351377;
#
# Epoch 14/20
# ----------
# train Loss: 0.4413; train Acc: 0.9306;
# validation Loss: 3.3918; validation Acc: 0.6398;
# epoch: 14; lr: 0.009538887392664544;
#
# Epoch 15/20
# ----------
# train Loss: 0.4462; train Acc: 0.9250;
# validation Loss: 1.9293; validation Acc: 0.7826;
# epoch: 15; lr: 0.00010926199633097155;
#
# Epoch 16/20
# ----------
# train Loss: 0.3786; train Acc: 0.9362;
# validation Loss: 1.8126; validation Acc: 0.7640;
# epoch: 16; lr: 0.001706552699406599;
#
# Epoch 17/20
# ----------
# train Loss: 0.3971; train Acc: 0.9306;
# validation Loss: 2.5581; validation Acc: 0.6770;
# epoch: 17; lr: 0.0046164048593659085;
#
# Epoch 18/20
# ----------
# train Loss: 0.2937; train Acc: 0.9418;
# validation Loss: 3.0365; validation Acc: 0.7019;
# epoch: 18; lr: 0.007679133974894983;
#
# Epoch 19/20
# ----------
# train Loss: 0.3427; train Acc: 0.9362;
# validation Loss: 1.8662; validation Acc: 0.7764;
# epoch: 19; lr: 0.009674128381980071;
#
# Epoch 20/20
# ----------
# train Loss: 0.4460; train Acc: 0.9337;
# validation Loss: 2.0283; validation Acc: 0.7453;
# epoch: 20; lr: 0.00019369152030840553;
#
# Training complete in 32m 16s
# Best validation Acc: 0.788820
# /opt/ml/model/model.pth
#
# Evaluating best weights:
# --------------------
# train Loss: 0.0607 Acc: 0.9857
# train Avg. F1 Score: 0.986;
# classification_report:
#               precision    recall  f1-score   support
#
#         back       0.95      0.99      0.97       225
#        front       0.99      0.96      0.98       253
#         side       0.99      0.99      0.99      1136
#
#     accuracy                           0.99      1614
#    macro avg       0.98      0.98      0.98      1614
# weighted avg       0.99      0.99      0.99      1614
# ;
#
# validation Loss: 1.7107 Acc: 0.7888
# validation Avg. F1 Score: 0.789;
# classification_report:
#               precision    recall  f1-score   support
#
#         back       0.71      0.86      0.78        35
#        front       0.82      0.73      0.77        51
#         side       0.81      0.80      0.81        75
#
#     accuracy                           0.79       161
#    macro avg       0.78      0.79      0.79       161
# weighted avg       0.79      0.79      0.79       161
# ;
#
#
# 2021-06-02 10:27:31 Uploading - Uploading generated training modeltest Loss: 2.9112 Acc: 0.7121
# test Avg. F1 Score: 0.736;
# classification_report:
#               precision    recall  f1-score   support
#
#         back       0.39      1.00      0.57        54
#        front       0.54      1.00      0.70        36
#         side       1.00      0.63      0.77       306
#
#     accuracy                           0.71       396
#    macro avg       0.64      0.88      0.68       396
# weighted avg       0.88      0.71      0.74       396
# ;
#
# 2021-06-02 10:27:28,448 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2021-06-02 10:27:59 Completed - Training job completed
# ProfilerReport-1622627347: IssuesFound
# Training seconds: 2190
# Billable seconds: 2190
